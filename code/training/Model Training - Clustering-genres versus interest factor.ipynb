# %%
# import the library
# %matplotlib inline

import pandas as pd
import numpy as np
import collections
import matplotlib.pyplot as plt
import seaborn as sns

from sklearn.cluster import KMeans
from sklearn.preprocessing import StandardScaler
from sklearn.metrics.pairwise import euclidean_distances

sns.set_style('whitegrid')

# %% [markdown]
# # Load Data

# %%
tracks = pd.read_csv('../../data/processed/tracks_genres.csv', dtype=object)

tracks = tracks.set_index(['genres'])

tracks.head()
# Out:
#                                             Unnamed: 0 track_id  \
# genres
# Hip-Hop                                              0        2
# Hip-Hop                                              1        3
# Hip-Hop                                              2        5
# Pop                                                  3       10
# Folk,Pop,Experimental Pop,Singer-Songwriter          4       20
#
#                                             album_date_created  \
# genres
# Hip-Hop                                        2008-11-26 1:44
# Hip-Hop                                        2008-11-26 1:44
# Hip-Hop                                        2008-11-26 1:44
# Pop                                            2008-11-26 1:45
# Folk,Pop,Experimental Pop,Singer-Songwriter    2008-11-26 1:45
#
#                                             album_date_released  \
# genres
# Hip-Hop                                         2009-01-05 0:00
# Hip-Hop                                         2009-01-05 0:00
# Hip-Hop                                         2009-01-05 0:00
# Pop                                             2008-02-06 0:00
# Folk,Pop,Experimental Pop,Singer-Songwriter     2009-01-06 0:00
#
#                                             album_favorites album_id  \
# genres
# Hip-Hop                                                   4        1
# Hip-Hop                                                   4        1
# Hip-Hop                                                   4        1
# Pop                                                       4        6
# Folk,Pop,Experimental Pop,Singer-Songwriter               2        4
#
#                                             album_listens album_tags  \
# genres
# Hip-Hop                                              6073         []
# Hip-Hop                                              6073         []
# Hip-Hop                                              6073         []
# Pop                                                 47632         []
# Folk,Pop,Experimental Pop,Singer-Songwriter          2710         []
#
#                                                       album_title  \
# genres
# Hip-Hop                                      AWOL - A Way Of Life
# Hip-Hop                                      AWOL - A Way Of Life
# Hip-Hop                                      AWOL - A Way Of Life
# Pop                                             Constant Hitmaker
# Folk,Pop,Experimental Pop,Singer-Songwriter                 Niris
#
#                                             album_tracks     ...      \
# genres                                                       ...
# Hip-Hop                                                7     ...
# Hip-Hop                                                7     ...
# Hip-Hop                                                7     ...
# Pop                                                    2     ...
# Folk,Pop,Experimental Pop,Singer-Songwriter           13     ...
#
#                                             track_interest  \
# genres
# Hip-Hop                                               4656
# Hip-Hop                                               1470
# Hip-Hop                                               1933
# Pop                                                  54881
# Folk,Pop,Experimental Pop,Singer-Songwriter            978
#
#                                             track_language_code track_listens  \
# genres
# Hip-Hop                                                      en          1293
# Hip-Hop                                                      en           514
# Hip-Hop                                                      en          1151
# Pop                                                          en         50135
# Folk,Pop,Experimental Pop,Singer-Songwriter                  en           361
#
#                                             track_number      track_title  \
# genres
# Hip-Hop                                                3             Food
# Hip-Hop                                                4     Electric Ave
# Hip-Hop                                                6       This World
# Pop                                                    1          Freeway
# Folk,Pop,Experimental Pop,Singer-Songwriter            3  Spiritual Level
#
#                                             track_year_created  \
# genres
# Hip-Hop                                                   2008
# Hip-Hop                                                   2008
# Hip-Hop                                                   2008
# Pop                                                       2008
# Folk,Pop,Experimental Pop,Singer-Songwriter               2008
#
#                                             bit_rate_factor listens_factor  \
# genres
# Hip-Hop                                                 0.7              2
# Hip-Hop                                                 0.7              3
# Hip-Hop                                                 0.7              2
# Pop                                                     0.5              1
# Folk,Pop,Experimental Pop,Singer-Songwriter             0.7              4
#
#                                             interest_factor track_price
# genres
# Hip-Hop                                                   1        3.49
# Hip-Hop                                                 0.1        0.35
# Hip-Hop                                                 0.7        2.45
# Pop                                                       1         2.5
# Folk,Pop,Experimental Pop,Singer-Songwriter             0.1        0.35
#
# [5 rows x 49 columns]

# %%
X_columns=["interest_factor"]

tracks = tracks[X_columns]

# normalize the columns

track_norm = tracks.copy()
track_norm
for col in X_columns:
    track_norm[col] = StandardScaler().fit_transform(track_norm[col].values.reshape(-1, 1))

track_norm
# Out:
# /home/cloudera/anaconda3/lib/python3.6/site-packages/sklearn/utils/validation.py:475: DataConversionWarning: Data with input dtype object was converted to float64 by StandardScaler.
#   warnings.warn(msg, DataConversionWarning)
#                                                     interest_factor
# genres
# Hip-Hop                                                    1.294386
# Hip-Hop                                                   -1.321834
# Hip-Hop                                                    0.422313
# Pop                                                        1.294386
# Folk,Pop,Experimental Pop,Singer-Songwriter               -1.321834
# Folk,Pop,Experimental Pop,Singer-Songwriter               -1.321834
# Folk,Pop,Experimental Pop,Singer-Songwriter               -0.159069
# Folk,Pop,Experimental Pop,Singer-Songwriter               -0.740452
# Folk,Pop,Experimental Pop,Singer-Songwriter               -0.740452
# Hip-Hop                                                   -1.321834
# Psych-Rock,Rock,Loud-Rock                                  0.713004
# Psych-Rock,Rock,Loud-Rock                                  0.422313
# Noise,Avant-Garde,Experimental                             0.713004
# Noise,Avant-Garde,Experimental                             0.422313
# Folk                                                      -0.159069
# Folk                                                       0.422313
# Folk                                                      -1.321834
# Folk                                                      -1.321834
# Jazz                                                      -1.321834
# Jazz                                                      -1.321834
# Jazz                                                      -1.321834
# Jazz                                                      -1.321834
# Avant-Garde,Experimental                                   0.422313
# Avant-Garde,Experimental                                  -1.321834
# Avant-Garde,Experimental                                  -1.321834
# Punk,Rock                                                 -0.159069
# Punk,Rock                                                 -0.159069
# Post-Rock,Rock                                            -0.740452
# Post-Rock,Rock                                            -0.740452
# Post-Rock,Rock                                            -0.740452
# ...                                                             ...
# Avant-Garde,Krautrock,Experimental,Pop,Rock,Exp...        -0.159069
# Avant-Garde,Krautrock,Experimental,Pop,Rock,Exp...        -0.159069
# Avant-Garde,Krautrock,Experimental,Pop,Rock,Exp...        -0.159069
# Avant-Garde,Krautrock,Experimental,Pop,Rock,Exp...        -1.321834
# Avant-Garde,Krautrock,Experimental,Pop,Rock,Exp...        -0.159069
# Avant-Garde,Krautrock,Experimental,Pop,Rock,Exp...        -1.321834
# Avant-Garde,Krautrock,Experimental,Pop,Rock,Exp...        -1.321834
# Avant-Garde,Krautrock,Experimental,Pop,Rock,Exp...        -1.321834
# Avant-Garde,Krautrock,Experimental,Pop,Rock,Exp...        -0.159069
# Avant-Garde,Krautrock,Experimental,Pop,Rock,Exp...        -1.321834
# Avant-Garde,Krautrock,Experimental,Pop,Rock,Exp...        -0.740452
# Avant-Garde,Krautrock,Experimental,Pop,Rock,Exp...        -0.740452
# Avant-Garde,Krautrock,Experimental,Pop,Rock,Exp...        -0.740452
# Avant-Garde,Krautrock,Experimental,Pop,Rock,Exp...        -0.740452
# Avant-Garde,Krautrock,Experimental,Pop,Rock,Exp...        -0.740452
# Avant-Garde,Krautrock,Experimental,Pop,Rock,Exp...        -0.740452
# Avant-Garde,Krautrock,Experimental,Pop,Rock,Exp...        -0.159069
# Avant-Garde,Krautrock,Experimental,Pop,Rock,Exp...        -0.159069
# Avant-Garde,Krautrock,Experimental,Pop,Rock,Exp...        -1.321834
# Avant-Garde,Krautrock,Experimental,Pop,Rock,Exp...        -1.321834
# Avant-Garde,Krautrock,Experimental,Pop,Rock,Exp...        -1.321834
# Avant-Garde,Krautrock,Experimental,Pop,Rock,Exp...        -0.740452
# Avant-Garde,Krautrock,Experimental,Pop,Rock,Exp...        -0.740452
# Avant-Garde,Krautrock,Experimental,Pop,Rock,Exp...        -0.159069
# Avant-Garde,Krautrock,Experimental,Pop,Rock,Exp...        -1.321834
# Avant-Garde,Krautrock,Experimental,Pop,Rock,Exp...        -1.321834
# Avant-Garde,Krautrock,Experimental,Pop,Rock,Exp...        -0.740452
# Avant-Garde,Krautrock,Experimental,Pop,Rock,Exp...        -0.740452
# Avant-Garde,Krautrock,Experimental,Pop,Rock,Exp...        -0.740452
# Avant-Garde,Krautrock,Experimental,Pop,Rock,Exp...        -1.321834
#
# [105239 rows x 1 columns]

# %% [markdown]
# # Model Training

# %%
k = 10
kmeans = KMeans(n_clusters=k).fit(track_norm.values)

print(set(kmeans.labels_))
print(collections.Counter(kmeans.labels_))

tracks_results = tracks.copy()
track_norm['cluster'] = kmeans.labels_
tracks_results['cluster'] = kmeans.labels_
# Out:
# {0, 1, 3, 4, 5, 8}
# Counter({1: 28973, 0: 24284, 3: 16713, 8: 16325, 4: 15399, 5: 3545})

# %% [markdown]
# # Analyze the results

# %%
tracks_results = tracks_results.reset_index()
for cluster in sorted(set(kmeans.labels_)):
    print(collections.Counter(tracks_results[tracks_results['cluster']==cluster]['genres']).most_common(5))
    
n_clusters = len(set(kmeans.labels_))
for col in X_columns:
    print(col)
    i = 1
    plt.figure(figsize=(16,3))
    for cluster in sorted(set(kmeans.labels_)):
        plt.subplot(1, n_clusters, i)
        plt.hist(tracks_results[tracks_results['cluster']==cluster][col], label=str(cluster), alpha=0.3, bins=20)
        i += 1
    plt.show()
# Out:
# [('Rock', 1562), ('Folk', 1210), ('Electronic', 1100), ('Post-Punk,Rock,Punk', 837), ('Hip-Hop', 741)]
# [('Rock', 1824), ('Folk', 1386), ('Electronic', 1304), ('Post-Punk,Rock,Punk', 1226), ('Hip-Hop', 799)]
# [('Rock', 1220), ('Electronic', 888), ('Folk', 752), ('Post-Punk,Rock,Punk', 583), ('Hip-Hop', 552)]
# [('Rock', 1109), ('Folk', 817), ('Electronic', 702), ('Post-Punk,Rock,Punk', 581), ('Hip-Hop', 475)]
# [('Rock', 198), ('Electronic', 179), ('Folk', 164), ('Post-Punk,Rock,Punk', 133), ('Hip-Hop', 83)]
# [('Rock', 1048), ('Folk', 770), ('Electronic', 730), ('Post-Punk,Rock,Punk', 614), ('Hip-Hop', 470)]
# interest_factor
